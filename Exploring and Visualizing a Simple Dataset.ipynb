# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("E:\COURSES\DevelopersHub corporation\Datasets\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.plot(x = 'SepalLengthCm' ,y = 'PetalLengthCm', kind = 'scatter');

# %%
df.plot(x = 'SepalWidthCm' ,y = 'PetalWidthCm', kind = 'scatter');

# %%
# drop non numeric data
df_numeric = df.drop(columns=["Species"]) 
# Draw histogram for SepalLengthCm
plt.figure(figsize = (6,4))
plt.hist(df_numeric["SepalLengthCm"])
plt.title("Distrebution of SepalLength")
plt.xlabel('SepalLength in (cm)')
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
# Draw histogram for SepalWidthCm
plt.figure(figsize = (6,4))
plt.hist(df_numeric['SepalWidthCm'])
plt.title("distrebution of sepalwidth")
plt.xlabel('SepalWidthCm')
plt.ylabel('frequency')
plt.show()

# %%
# Draw histogram for PetalLengthCm
plt.figure(figsize = (6,4))
plt.hist(df_numeric['PetalLengthCm'])
plt.title("distrebution of PetalLength")
plt.xlabel('PetalLengthCm')
plt.ylabel('frequency')
plt.show()

# %%
# Draw histogram for PetalWidthCm
plt.figure(figsize = (6,4))
plt.hist(df_numeric['PetalWidthCm'])
plt.title("distrebution of PetalWidthCm")
plt.xlabel('PetalWidthCm')
plt.ylabel('frequency')
plt.show()

# %%
import numpy as np
# Replace inf and -inf with NaN, then drop them
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# %%
sns.scatterplot(data = df , x= 'SepalLengthCm' , y = 'SepalWidthCm');

# %%
sns.scatterplot(data = df , x= 'PetalLengthCm' , y = 'PetalWidthCm');

# %%
sns.scatterplot(data = df , x= 'SepalLengthCm' , y = 'PetalWidthCm');

# %%
sns.scatterplot(data = df , x= 'PetalLengthCm' , y = 'SepalWidthCm');

# %%
sns.histplot(data=df_numeric, x="SepalLengthCm")
plt.title("Distribution of Sepal Length (cm)")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency");
# Out:
# E:\4th samester\Machine Learning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data = df_numeric , x = 'SepalWidthCm')
plt.title("Distribution of Sepal Width (Cm)")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequency");
# Out:
# E:\4th samester\Machine Learning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data = df_numeric , x = 'PetalLengthCm')
plt.title("Distribution of Petal Length (Cm)")
plt.xlabel("Petal Length (Cm)")
plt.ylabel("Frequency");
# Out:
# E:\4th samester\Machine Learning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data = df_numeric , x= 'PetalWidthCm')
plt.title("Distribution of Petal Width (Cm)")
plt.xlabel("Petal Width (Cm)")
plt.ylabel("Frequency");
# Out:
# E:\4th samester\Machine Learning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))

# Create one box plot for each numeric column
sns.boxplot(data=df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']])

plt.title("Box Plots of Iris Dataset Features")
plt.ylabel("Centimeters")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
